# %% [markdown]
# ***AI Generates ART:***

# %% [raw]
# 1.Best Art Style:
# 2.Various Region:
# 3.Checking Popularity Score with Density:
# 4.Checking how much Tools are using in Art Style :
# 5.Checking the Type of Genre in Art:
# 6.Checking the Score of Region:
# 7.Type of Tools:
# 8.No of Arts in a Region:
# 9.Checking the count of various Platform:
# 10.Checking the Score by ID:
# 11.Checking Which Artwork Got Most Description:
# 12.Checking the Medium:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\LENOVO\Desktop\Data Science(SMSR)\AI generated ART\ai_generated_art_trends_2024.csv")

# %%
df
# Out:
#      Artwork_ID       Artist_Name      Art_Style Creation_Date         Medium  \
# 0     ART-00001            DALL-E     Conceptual    2023-03-11        Collage
# 1     ART-00002      AbstractoBot       Futurism    2022-11-27      Oil Paint
# 2     ART-00003           Vincent       Futurism    2024-03-13       Charcoal
# 3     ART-00004        ArtBreeder  Impressionism    2022-09-12  Pencil Sketch
# 4     ART-00005            DALL-E     Surrealism    2022-12-05        Collage
# ...         ...               ...            ...           ...            ...
# 9995  ART-09996         RenoirBot     Conceptual    2024-01-22      Oil Paint
# 9996  ART-09997         RenoirBot        Pop Art    2023-04-05  Acrylic Paint
# 9997  ART-09998        ArtBreeder       Futurism    2023-01-27       3D Model
# 9998  ART-09999  GenerativeGenius         Cubism    2022-10-04  Acrylic Paint
# 9999  ART-10000  GenerativeGenius       Abstract    2022-12-07  Pencil Sketch
#
# ...

# %%
df.columns
# Out:
# Index(['Artwork_ID', 'Artist_Name', 'Art_Style', 'Creation_Date', 'Medium',
#        'Tools_Used', 'Popularity_Score', 'Region', 'Art_Genre', 'Platform',
#        'Description', 'Image_URL'],
#       dtype='object')

# %%
df.describe(include="all")
# Out:
#        Artwork_ID Artist_Name Art_Style Creation_Date         Medium  \
# count       10000       10000     10000         10000          10000
# unique      10000          15        10           730             10
# top     ART-00001  MidJourney    Cubism    2023-05-02  Pencil Sketch
# freq            1         694      1050            28           1048
# mean          NaN         NaN       NaN           NaN            NaN
# std           NaN         NaN       NaN           NaN            NaN
# min           NaN         NaN       NaN           NaN            NaN
# 25%           NaN         NaN       NaN           NaN            NaN
# 50%           NaN         NaN       NaN           NaN            NaN
# 75%           NaN         NaN       NaN           NaN            NaN
# max           NaN         NaN       NaN           NaN            NaN
#
#        Tools_Used  Popularity_Score         Region Art_Genre  Platform  \
# ...

# %%
df.drop(["Image_URL"],axis=1,inplace=True)

# %%
df.dropna(how="any",inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artwork_ID        10000 non-null  object
#  1   Artist_Name       10000 non-null  object
#  2   Art_Style         10000 non-null  object
#  3   Creation_Date     10000 non-null  object
#  4   Medium            10000 non-null  object
#  5   Tools_Used        10000 non-null  object
#  6   Popularity_Score  10000 non-null  float64
#  7   Region            10000 non-null  object
#  8   Art_Genre         10000 non-null  object
#  9   Platform          10000 non-null  object
#  10  Description       10000 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 859.5+ KB

# %%
df.dtypes
# Out:
# Artwork_ID           object
# Artist_Name          object
# Art_Style            object
# Creation_Date        object
# Medium               object
# Tools_Used           object
# Popularity_Score    float64
# Region               object
# Art_Genre            object
# Platform             object
# Description          object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Artwork_ID          0
# Artist_Name         0
# Art_Style           0
# Creation_Date       0
# Medium              0
# Tools_Used          0
# Popularity_Score    0
# Region              0
# Art_Genre           0
# Platform            0
# Description         0
# dtype: int64

# %%
df["Art_Style"].unique()
# Out:
# array(['Conceptual', 'Futurism', 'Impressionism', 'Surrealism',
#        'Abstract', 'Realism', 'Minimalism', 'Pop Art', 'Cubism',
#        'Expressionism'], dtype=object)

# %%
df.Popularity_Score
# Out:
# 0       1604.25
# 1       4162.12
# 2       2989.38
# 3       2985.97
# 4       2035.18
#          ...
# 9995    3886.42
# 9996    4715.45
# 9997     741.83
# 9998    2229.60
# 9999    3815.99
# Name: Popularity_Score, Length: 10000, dtype: float64

# %%
df['Popularity_Score'].unique()
# Out:
# array([1604.25, 4162.12, 2989.38, ...,  741.83, 2229.6 , 3815.99])

# %%
df_Score=lambda x: str(x).split('/')[0]
df.Popularity_Score=df.Popularity_Score.apply(df_Score)
df['Popularity_Score'].head()
# Out:
# 0    1604.25
# 1    4162.12
# 2    2989.38
# 3    2985.97
# 4    2035.18
# Name: Popularity_Score, dtype: object

# %%
df.Tools_Used
# Out:
# 0         GANPaint
# 1       MidJourney
# 2         GANPaint
# 3       ArtBreeder
# 4        DeepDream
#            ...
# 9995      GANPaint
# 9996      GANPaint
# 9997     DeepDream
# 9998      GANPaint
# 9999     DeepDream
# Name: Tools_Used, Length: 10000, dtype: object

# %%
df["Tools_Used"].unique()
# Out:
# array(['GANPaint', 'MidJourney', 'ArtBreeder', 'DeepDream', 'DALL-E'],
#       dtype=object)

# %%
df["Tools_Used"]=df["Tools_Used"].map({"GANPaint":1,"MidJourney":2,"ArtBreeder":3,"DeepDream":4,"DALL-E":5})

# %%
df.shape
# Out:
# (10000, 11)

# %%
df.size
# Out:
# 110000

# %%
df.describe()
# Out:
#          Tools_Used
# count  10000.000000
# mean       2.996000
# std        1.415692
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %% [markdown]
# ***DATA VISULIZATION:***

# %% [markdown]
# ***1.Best Art Style:***

# %%
df['Art_Style'].value_counts()[:].plot(kind='line',figsize=(20,10),color='purple',title='Art Style').grid(color = 'brown',linewidth =0.7)

# %% [markdown]
# ***2.Various Region:***

# %%
df.groupby('Region')['Artwork_ID'].count().nlargest(8).plot(kind = 'pie')
# Out:
# <Axes: ylabel='Artwork_ID'>

# %% [markdown]
# ***3.Checking Popularity Score with Density:***

# %%
sns.distplot(df['Popularity_Score'])
font = {'family':'serif','color':'brown','size':20}
plt.title('Popularity Score',fontdict=font)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18636\2404851870.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Popularity_Score'])
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ***4.Checking how much Tools are using in Art Style :***

# %%
sns.violinplot(x= df['Tools_Used'], y= df['Art_Style'])
plt.show()

# %% [markdown]
# ***5.Checking the Type of Genre in Art:***

# %%
ig =plt.subplots(figsize =(11,10))
df['Art_Genre'].value_counts().head(10).plot(kind='pie', autopct = '%1.1f%%')
plt.legend(title = "Art Genre:")

# %% [markdown]
# ***6.Checking the Score of Region:***

# %%
art_type= df.groupby(['Region','Popularity_Score'])['Artwork_ID'].count()

# %%
art_type
# Out:
# Region         Popularity_Score
# Africa         1000.02             1
#                1002.8              1
#                1006.79             1
#                1007.68             1
#                101.91              1
#                                   ..
# South America  99.72               1
#                995.19              1
#                995.48              1
#                996.33              1
#                999.24              1
# Name: Artwork_ID, Length: 9984, dtype: int64

# %%
art_type.plot(kind= 'bar', figsize= (30,15))
plt.title("Art Order",size=25)
# Out:
# Text(0.5, 1.0, 'Art Order')

# %% [markdown]
# ***7.Type of Tools:***

# %%
df['Tools_Used'].value_counts()[:20].plot(kind='bar', figsize=(20,7))
plt.title('Types of Tools used in Art by AI')
# Out:
# Text(0.5, 1.0, 'Types of Tools used in Art by AI')

# %%
df.head(2)
# Out:
#   Artwork_ID   Artist_Name   Art_Style Creation_Date     Medium  Tools_Used  \
# 0  ART-00001        DALL-E  Conceptual    2023-03-11    Collage           1
# 1  ART-00002  AbstractoBot    Futurism    2022-11-27  Oil Paint           2
#
#   Popularity_Score         Region Art_Genre   Platform  \
# 0          1604.25  South America     Urban  Instagram
# 1          4162.12  North America  Abstract   Dribbble
#
#                                          Description
# 0  A mesmerizing piece of art that blends traditi...
# 1  A mesmerizing piece of art that blends traditi...

# %% [markdown]
# ***8.No of Arts in a Region:***

# %%
plt.figure(figsize=(15,5))
a=df['Art_Style'].value_counts()[:15]
sns.barplot(x=a,y=a.index,palette='rainbow')
plt.title('Number of Style of Arts')
plt.xlabel("Number of Arts",size=15)
plt.ylabel("Art_Style",size=15)
# Out:
# Text(0, 0.5, 'Art_Style')

# %% [markdown]
# ***9.Checking the count of various Platform:***

# %%
df["Platform"].value_counts()
# Out:
# Platform
# Dribbble      1086
# ArtStation    1039
# Flickr        1025
# Instagram     1017
# Twitter       1004
# Tumblr         995
# Reddit         969
# Pinterest      964
# Behance        951
# DeviantArt     950
# Name: count, dtype: int64

# %%
plt.subplots(figsize=(10,8))
sns.countplot(x ='Platform', data = df, palette='spring')
plt.title('Various Platform')
# Out:
# Text(0.5, 1.0, 'Various Platform')

# %% [markdown]
# ***10.Checking the Score by ID:***

# %%
plt.figure(figsize=(20,25))
sns.scatterplot(x='Popularity_Score',y='Artwork_ID',data=df)
plt.xlabel('Score',size=20)
plt.ylabel('ID',size=25)

# %% [markdown]
# ***11. Checking Which Artwork Got Most Description:***

# %%
artwork_id_df = df[['Artwork_ID','Description']]

# %%
artwork_id_df.drop_duplicates()
# Out:
#      Artwork_ID                                        Description
# 0     ART-00001  A mesmerizing piece of art that blends traditi...
# 1     ART-00002  A mesmerizing piece of art that blends traditi...
# 2     ART-00003  A mesmerizing piece of art that blends traditi...
# 3     ART-00004  A mesmerizing piece of art that blends traditi...
# 4     ART-00005  A mesmerizing piece of art that blends traditi...
# ...         ...                                                ...
# 9995  ART-09996  A mesmerizing piece of art that blends traditi...
# 9996  ART-09997  A mesmerizing piece of art that blends traditi...
# 9997  ART-09998  A mesmerizing piece of art that blends traditi...
# 9998  ART-09999  A mesmerizing piece of art that blends traditi...
# 9999  ART-10000  A mesmerizing piece of art that blends traditi...
#
# [10000 rows x 2 columns]

# %% [markdown]
# ***12.Checking the Medium:***

# %%
ig =plt.subplots(figsize =(10,10))
df['Medium'].value_counts().head(10).plot(kind='pie', autopct = '%1.1f%%',shadow=True)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ***EDA:***

# %%
df.hist(figsize=(10,10),color="olive")
# Out:
# array([[<Axes: title={'center': 'Tools_Used'}>]], dtype=object)

# %% [markdown]
# ***BIVARIANT ANALYSIS:***

# %%
sns.pairplot(df)
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
